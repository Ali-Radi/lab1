# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Radi/lab1/blob/main/matplotlib_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Practice
#
# This notebook offers a set of exercises to different tasks with Matplotlib.
#
# It should be noted there may be more than one different way to answer a question or complete an exercise.
#
# Different tasks will be detailed by comments or text.

# %%
# Import the pyplot module from matplotlib as plt and make sure
# plots appear in the notebook using '%matplotlib inline'
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a simple plot using plt.plot()
plt.plot()
# Out:
# []

# %%
# Plot a single Python list
plt.plot([1, 2, 3, 4])

# %%
# Create two lists, one called x, one called y, each with 5 numbers in them
x = [1, 2, 3, 4, 5]
y = [6, 7, 8, 9, 10]

# %%
# Plot x & y (the lists you've created)
plt.plot(x, y)

# %% [markdown]
# There's another way to create plots with Matplotlib, it's known as the object-orientated (OO) method. Let's try it.

# %%
# Create a plot using plt.subplots()
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
# Create a plot using plt.subplots() and then add x & y on the axes
fig , ax = plt.subplots()
ax.plot(x, y)

# %% [markdown]
# Now let's try a small matplotlib workflow.

# %%
# Import and get matplotlib ready
import matplotlib.pyplot as plt

# Prepare data (create two lists of 5 numbers, x & y)
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Setup figure and axes using plt.subplots()
fig, ax = plt.subplots()

# Add data (x, y) to axes
ax.plot(x, y)

# Customize plot by adding a title, xlabel and ylabel
ax.set_title("Simple Line Plot")
ax.set_xlabel("x values")
ax.set_ylabel("Y values")

# Save the plot to file using fig.savefig()
fig.savefig("my_plot.png")

# (Optional) Show the plot inside Colab/Notebook
plt.show()

# %% [markdown]
# Okay, this is a simple line plot, how about something a little different?
#
# To help us, we'll import NumPy.

# %%
#Import NumPy as np
import numpy as np

# %%
# Create an array of 100 evenly spaced numbers between 0 and 100 using NumPy and save it to variable x
x = np.linspace(0, 100, 100)
print(x)
# Out:
# [  0.           1.01010101   2.02020202   3.03030303   4.04040404
#    5.05050505   6.06060606   7.07070707   8.08080808   9.09090909
#   10.1010101   11.11111111  12.12121212  13.13131313  14.14141414
#   15.15151515  16.16161616  17.17171717  18.18181818  19.19191919
#   20.2020202   21.21212121  22.22222222  23.23232323  24.24242424
#   25.25252525  26.26262626  27.27272727  28.28282828  29.29292929
#   30.3030303   31.31313131  32.32323232  33.33333333  34.34343434
#   35.35353535  36.36363636  37.37373737  38.38383838  39.39393939
#   40.4040404   41.41414141  42.42424242  43.43434343  44.44444444
#   45.45454545  46.46464646  47.47474747  48.48484848  49.49494949
#   50.50505051  51.51515152  52.52525253  53.53535354  54.54545455
#   55.55555556  56.56565657  57.57575758  58.58585859  59.5959596
#   60.60606061  61.61616162  62.62626263  63.63636364  64.64646465
#   65.65656566  66.66666667  67.67676768  68.68686869  69.6969697
#   70.70707071  71.71717172  72.72727273  73.73737374  74.74747475
#   75.75757576  76.76767677  77.77777778  78.78787879  79.7979798
#   80.80808081  81.81818182  82.82828283  83.83838384  84.84848485
#   85.85858586  86.86868687  87.87878788  88.88888889  89.8989899
#   90.90909091  91.91919192  92.92929293  93.93939394  94.94949495
#   95.95959596  96.96969697  97.97979798  98.98989899 100.        ]

# %%
# Create a plot using plt.subplots() and plot x versus x^2 (x squared)
plt.subplots()
plt.plot(x, x**2)

# %% [markdown]
# We'll start with scatter plots.

# %%
# Create a scatter plot of x versus the exponential of x (np.exp(x))
plt.scatter(x, np.exp(x))

# %%
# Create a scatter plot of x versus np.sin(x)
plt.scatter(x , np.sin(x))

# %% [markdown]
# How about we try another type of plot? This time let's look at a bar plot. First we'll make some data.

# %%
# Create a Python dictionary of 3 of your favourite foods with
# The keys of the dictionary should be the food name and the values their price
favourite_foods = {
    "Pizza": 10,
    "Burger": 5,
    "Salad": 3
}

# %%
# Create a bar graph where the x-axis is the keys of the dictionary
# and the y-axis is the values of the dictionary
plt.bar(favourite_foods.keys(), favourite_foods.values())


# Add a title, xlabel and ylabel to the plot
plt.title("My Favourite Foods")
plt.xlabel("Food")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
# Make the same plot as above, except this time make the bars go horizontal
plt.barh(favourite_foods.keys(),favourite_foods.values())

# Add a title, xlabel and ylabel to the plot
plt.title("My Favourite Foods")
plt.xlabel("Price")
plt.ylabel("Food")
# Out:
# Text(0, 0.5, 'Food')

# %% [markdown]
# All this food plotting is making me hungry. But we've got a couple of plots to go.
#
# Let's see a histogram.

# %%
# Create a random NumPy array of 1000 normally distributed numbers using NumPy and save it to x
x = np.random.randn(1000)


# Create a histogram plot of x
plt.hist(x)
# Out:
# (array([  7.,  37., 128., 223., 286., 191.,  91.,  27.,   7.,   3.]),
#  array([-2.97560486, -2.29892501, -1.62224516, -0.94556531, -0.26888545,
#          0.4077944 ,  1.08447425,  1.7611541 ,  2.43783395,  3.1145138 ,
#          3.79119365]),
#  <BarContainer object of 10 artists>)

# %%
# Create a NumPy array of 1000 random numbers and save it to x
x = np.random.randn(1000)


# Create a histogram plot of x
plt.hist(x)
# Out:
# (array([  3.,  23.,  56., 153., 235., 249., 178.,  79.,  21.,   3.]),
#  array([-3.26149454, -2.61287699, -1.96425945, -1.3156419 , -0.66702436,
#         -0.01840681,  0.63021073,  1.27882828,  1.92744582,  2.57606337,
#          3.22468091]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Notice how the distributions (spread of data) are different. Why do they differ?
#
# What else can you find out about the normal distribution?
#
# Can you think of any other kinds of data which may be normally distributed?
#
# These questions aren't directly related to plotting or Matplotlib but they're helpful to think of.
#
# Now let's try make some subplots. A subplot is another name for a figure with multiple plots on it.

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
plt.subplots(2, 2)
# Out:
# (<Figure size 640x480 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %% [markdown]
# Notice how the subplot has multiple figures. Now let's add data to each axes.

# %%
# Create the same plot as above with 2 rows and 2 columns and figsize of (10, 5)
fig, ax = plt.subplots(2, 2, figsize=(10, 5))

# Plot x versus x/2 on the top left axes
ax[0, 0].plot(x, x/2)
# Plot a scatter plot of 10 random numbers on each axis on the top right subplot
ax[0, 1].scatter(np.random.randn(10), np.random.randn(10))

# Plot a bar graph of the favourite food keys and values on the bottom left subplot
ax[1, 0].bar(favourite_foods.keys(), favourite_foods.values())

# Plot a histogram of 1000 random normally distributed numbers on the bottom right subplot
ax[1, 1].hist(np.random.randn(1000))
# Out:
# (array([  8.,  37.,  79., 145., 222., 227., 144.,  97.,  31.,  10.]),
#  array([-2.92484879, -2.34168674, -1.75852469, -1.17536263, -0.59220058,
#         -0.00903853,  0.57412352,  1.15728557,  1.74044763,  2.32360968,
#          2.90677173]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Woah. There's a lot going on there.
#
# Now we've seen how to plot with Matplotlib and data directly. Let's practice using Matplotlib to plot with pandas.
#
# First we'll need to import pandas and create a DataFrame work with.

# %%
# Import pandas as pd
import pandas as pd

# %%
# Import the '../data/car-sales.csv' into a DataFame called car_sales and view
from google.colab import drive
drive.mount('/content/drive')
car_sales = pd.read_csv('/content/drive/MyDrive/data/car-sales.csv')
car_sales.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Try to plot the 'Price' column using the plot() function
car_sales['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1563476681.py in <cell line: 0>()
#       1 # Try to plot the 'Price' column using the plot() function
# ----> 2 car_sales['Price'].plot()
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     497     @final
#     498     def generate(self) -> None:
# --> 499         self._compute_plot_data()
#     500         fig = self.fig
#     501         self._make_plot(fig)
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     696         # no non-numeric frames or series allowed
#     697         if is_empty:
# --> 698             raise TypeError("no numeric data to plot")
#     699
#     700         self.data = numeric_data.apply(type(self)._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# Why doesn't it work?
#
# Hint: It's not numeric data.
#
# In the process of turning it to numeric data, let's create another column which adds the total amount of sales and another one which shows what date the car was sold.
#
# Hint: To add a column up cumulatively, look up the cumsum() function. And to create a column of dates, look up the date_range() function.

# %%
# Remove the symbols and convert the 'Price' column to numbers
car_sales['Price'] = car_sales['Price'].astype(str).str.replace(r'[\$\,]', '', regex=True)
car_sales['Price'] = car_sales['Price'].astype(float).astype(int)

# %%
# Add a column called 'Total Sales' to car_sales which cumulatively adds the 'Price' column (cumsum())
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# Add a column called 'Sale Date' which lists a series of successive dates starting from today (your today)
car_sales['Sale Date'] = pd.date_range('2023-08-19', periods=len(car_sales))

# View the car_sales DataFrame
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2023-08-19
# 1   Honda    Red          87899      4   5000         9000 2023-08-20
# 2  Toyota   Blue          32549      3   7000        16000 2023-08-21
# 3     BMW  Black          11179      5  22000        38000 2023-08-22
# 4  Nissan  White         213095      4   3500        41500 2023-08-23
# 5  Toyota  Green          99213      4   4500        46000 2023-08-24
# 6   Honda   Blue          45698      4   7500        53500 2023-08-25
# 7   Honda   Blue          54738      4   7000        60500 2023-08-26
# 8  Toyota  White          60000      4   6250        66750 2023-08-27
# 9  Nissan  White          31600      4   9700        76450 2023-08-28

# %% [markdown]
# Now we've got a numeric column (`Total Sales`) and a dates column (`Sale Date`), let's visualize them.

# %%
# Use the plot() function to plot the 'Sale Date' column versus the 'Total Sales' column
car_sales.plot(x='Sale Date', y='Total Sales')
# Out:
# <Axes: xlabel='Sale Date'>

# %%
# Convert the 'Price' column to the integers
car_sales['Price'] = car_sales['Price'].astype(int)

# Create a scatter plot of the 'Odometer (KM)' and 'Price' column using the plot() function
car_sales.plot(x='Odometer (KM)', y='Price', kind='scatter')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Create a NumPy array of random numbers of size (10, 4) and save it to x
x = np.random.rand(10, 4)

# Turn the NumPy array x into a DataFrame with columns called ['a', 'b', 'c', 'd']
x = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
# Create a bar graph of the DataFrame
x.plot(kind='bar')
# Out:
# <Axes: >

# %%
# Create a bar graph of the 'Make' and 'Odometer (KM)' columns in the car_sales DataFrame
car_sales.plot(x='Make', y = 'Odometer (KM)', kind = 'bar')
# Out:
# <Axes: xlabel='Make'>

# %%
# Create a histogram of the 'Odometer (KM)' column
car_sales['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
# Create a histogram of the 'Price' column with 20 bins
car_sales['Price'].hist(bins=20)
# Out:
# <Axes: >
